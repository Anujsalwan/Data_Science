# %% [markdown]
# # Settings to be changed in VS Code
#
#
#
# ![image.png](attachment:image.png)

# %%
from google.colab import drive
# 1. Mount Google Drive
drive.mount('/content/drive')

# %%
file_path = "/content/drive/MyDrive/DATA SCIENCE DATA"

# %%
student_attendance=pd.read_excel(file_path +"/" +"Student Performance Analysis.xlsx",sheet_name="Attendance")
student_attendance.head()
